# %%
import pandas as pd

# %%
df_csv = pd.read_csv('../data/rawLA311/2016MyLA311ServiceRequestData.csv', low_memory=False, 
                     dtype={
                    'Suffix': 'str',
                     }
                    
                    )

# %%
df = df_csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952486 entries, 0 to 952485
# Data columns (total 33 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   SRNumber            952486 non-null  object
#  1   CreatedDate         952486 non-null  object
#  2   UpdatedDate         952486 non-null  object
#  3   ActionTaken         952486 non-null  object
#  4   Owner               952486 non-null  object
#  5   RequestType         952486 non-null  object
#  6   Status              952486 non-null  object
#  7   RequestSource       952486 non-null  object
#  8   MobileOS            138439 non-null  object
#  9   Anonymous           952486 non-null  object
#  10  AssignTo            933975 non-null  object
#  11  ServiceDate         901474 non-null  object
#  12  ClosedDate          952486 non-null  object
#  13  AddressVerified     952486 non-null  object
#  14  ApproximateAddress  707595 non-null  object
# ...

# %%
df.head(5)
# Out:
#      SRNumber             CreatedDate             UpdatedDate ActionTaken  \
# 0  1-88224881  01/01/2016 08:12:00 AM  01/07/2016 07:39:00 AM  SR Created
# 1  1-88224921  01/01/2016 08:15:00 AM  01/02/2016 07:19:00 AM  SR Created
# 2  1-88225061  01/01/2016 08:26:00 AM  01/04/2016 02:39:00 PM  SR Created
# 3  1-88226921  01/01/2016 08:28:00 AM  01/04/2016 02:52:00 PM  SR Created
# 4  1-88227021  01/01/2016 08:29:00 AM  01/04/2016 12:31:00 PM  SR Created
#
#   Owner                 RequestType  Status RequestSource MobileOS Anonymous  \
# 0   BOS      Illegal Dumping Pickup  Closed          Call      NaN         N
# 1   BOS         Dead Animal Removal  Closed          Call      NaN         Y
# 2   BOS         Dead Animal Removal  Closed          Call      NaN         N
# 3   BOS                 Bulky Items  Closed          Call      NaN         N
# 4   BOS  Metal/Household Appliances  Closed          Call      NaN         N
#
# ...

# %%
len('RequestType')
# Out:
# 11

# %%
df.value_counts('RequestType')
# Out:
# RequestType
# Bulky Items                   414518
# Graffiti Removal              311099
# Metal/Household Appliances     60511
# Illegal Dumping Pickup         52871
# Electronic Waste               41330
# Dead Animal Removal            24191
# Other                          15497
# Homeless Encampment            14717
# Single Streetlight Issue       11582
# Multiple Streetlight Issue      4006
# Report Water Waste              1593
# Feedback                         571
# dtype: int64

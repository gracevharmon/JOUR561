# %%
import pandas as pd

# %%
df_csv = pd.read_csv('../data/raw/December_2014_Permits.csv')
# Out:
# /Users/graceharmon/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df = df_csv

# %%
df.head()
# Out:
#    Assessor Book Assessor Page Assessor Parcel                          Tract  \
# 0         5017.0          25.0             015  MILHOUSE VERMONT AVENUE TRACT
# 1         5478.0          17.0             040                        TR 2596
# 2         4422.0           6.0             007                        TR 9300
# 3         4260.0          17.0             024                        TR 8369
# 4         5561.0           6.0             041                       P M 3813
#
#   Block Lot Reference # (Old Permit #)      PCIS Permit #        Permit Type  \
# 0   NaN   3                        NaN  20041-10000-19010         Electrical
# 1   NaN  99                        NaN  19041-10000-34160         Electrical
# 2    80   3                  20WL05483  16030-30001-00598  Bldg-Alter/Repair
# 3   NaN  60                        NaN  20043-10000-04664     Fire Sprinkler
# 4   NaN   C                  20WL06519  16010-30003-05895      Bldg-Addition
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1164250 entries, 0 to 1164249
# Data columns (total 52 columns):
#  #   Column                                    Non-Null Count    Dtype
# ---  ------                                    --------------    -----
#  0   Assessor Book                             1163365 non-null  float64
#  1   Assessor Page                             1163365 non-null  object
#  2   Assessor Parcel                           1163365 non-null  object
#  3   Tract                                     1159780 non-null  object
#  4   Block                                     223014 non-null   object
#  5   Lot                                       1156720 non-null  object
#  6   Reference # (Old Permit #)                505301 non-null   object
#  7   PCIS Permit #                             1164250 non-null  object
#  8   Permit Type                               1164250 non-null  object
# ...

# %%
df.columns = df.columns.str.upper()

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['ASSESSOR_BOOK', 'ASSESSOR_PAGE', 'ASSESSOR_PARCEL', 'TRACT', 'BLOCK',
#        'LOT', 'REFERENCE_#_(OLD_PERMIT_#)', 'PCIS_PERMIT_#', 'PERMIT_TYPE',
#        'PERMIT_SUB-TYPE', 'PERMIT_CATEGORY', 'PROJECT_NUMBER', 'EVENT_CODE',
#        'INITIATING_OFFICE', 'ISSUE_DATE', 'ADDRESS_START',
#        'ADDRESS_FRACTION_START', 'ADDRESS_END', 'ADDRESS_FRACTION_END',
#        'STREET_DIRECTION', 'STREET_NAME', 'STREET_SUFFIX', 'SUFFIX_DIRECTION',
#        'UNIT_RANGE_START', 'UNIT_RANGE_END', 'ZIP_CODE', 'WORK_DESCRIPTION',
#        'VALUATION', 'FLOOR_AREA-L.A._ZONING_CODE_DEFINITION',
#        '#_OF_RESIDENTIAL_DWELLING_UNITS', '#_OF_STORIES',
#        'CONTRACTOR'S_BUSINESS_NAME', 'CONTRACTOR_ADDRESS', 'CONTRACTOR_CITY',
#        'CONTRACTOR_STATE', 'LICENSE_TYPE', 'LICENSE_#', 'PRINCIPAL_FIRST_NAME',
#        'PRINCIPAL_MIDDLE_NAME', 'PRINCIPAL_LAST_NAME',
#        'LICENSE_EXPIRATION_DATE', 'APPLICANT_FIRST_NAME',
# ...

# %%
df.sort_values('PERMIT_TYPE' , ascending=False).head()
# Out:
#         ASSESSOR_BOOK ASSESSOR_PAGE ASSESSOR_PARCEL     TRACT BLOCK  LOT  \
# 602207         5588.0           020             029   TR 3733   NaN  157
# 752187         5529.0           023             020   TR 3425   NaN   34
# 421894         5527.0           5.0             003   TR 4849   NaN  141
# 421891         5432.0          15.0             020   TR 8423   NaN   37
# 752193         2234.0           011             031  TR 14014   NaN   33
#
#        REFERENCE_#_(OLD_PERMIT_#)      PCIS_PERMIT_#        PERMIT_TYPE  \
# 602207                  17LA84605  16047-10001-00204  Swimming-Pool/Spa
# 752187                  16VN10721  16047-20000-00022  Swimming-Pool/Spa
# 421894                  18VN76443  18047-20000-00674  Swimming-Pool/Spa
# 421891                  17WL83032  17047-30000-01458  Swimming-Pool/Spa
# 752193                  19VN86984  19047-20000-00216  Swimming-Pool/Spa
#
#                PERMIT_SUB-TYPE  ... APPLICANT_LAST_NAME  \
# ...

# %%
df.sort_values('PERMIT_TYPE' , ascending=True).head()
# Out:
#         ASSESSOR_BOOK ASSESSOR_PAGE ASSESSOR_PARCEL               TRACT BLOCK  \
# 867819         4241.0           007             016  VENICE ANNEX NO. 2     1
# 626426         2014.0           4.0             019            TR 21396   NaN
# 40467          2639.0           034             004            TR 15442   NaN
# 407457         2524.0           030             033            TR 13778   NaN
# 40476          4392.0           008             009             TR 6415   NaN
#
#        LOT REFERENCE_#_(OLD_PERMIT_#)      PCIS_PERMIT_#    PERMIT_TYPE  \
# 867819  16                  16WL73541  14014-10000-05112  Bldg-Addition
# 626426  87                  18SL63969  18014-70000-02081  Bldg-Addition
# 40467   14                  20VN14567  20014-20000-00512  Bldg-Addition
# 407457  52                  16VN29854  16014-20000-04882  Bldg-Addition
# 40476   75                  20WL05173  17014-10000-01216  Bldg-Addition
#
#                PERMIT_SUB-TYPE  ... APPLICANT_LAST_NAME  \
# ...

# %%
df['APPLICANT_ADDRESS_3'].to_list()
# Out:
# [nan,
#  nan,
#  nan,
#  'Van Nuys',
#  nan,
#  'SANTA ANA, CA',
#  nan,
#  'VAN NUYS,CA',
#  'Yucaipa',
#  nan,
#  '-',
#  'LOS ANGELES CA',
#  'VALLEY VILLAGE, CA',
#  nan,
#  'VAN NUYS, CA',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Los Angeles',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'van nuys',
#  'LOS ANGELES, CA',
#  'HUNTINGTON BEACH, CA',
#  nan,
#  'WOODLAND HILLS, CA',
#  nan,
#  'LOS ANGELES, CA',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'LOS ANGELES, CA',
#  'WEST HILLS, CA',
#  nan,
#  'CANOGA PARK, CA',
#  nan,
#  'SHERMAN OAKS, CA',
#  'WOODLAND HILLS, CA',
#  nan,
#  nan,
#  'CORONA, CA',
#  'BURBANK, CA',
#  nan,
#  nan,
#  'SUN VALLEY, CA',
#  'TARZANA',
#  nan,
#  'VENICE, CA',
#  'SANTA MONICA, CA',
#  nan,
#  nan,
#  nan,
#  nan,
#  'SH OAKS, CA',
#  nan,
#  'SUNLAND, CA',
#  'LOS ANGELES, CA',
#  nan,
#  nan,
#  nan,
#  'RESEDA, CA',
#  nan,
#  nan,
#  nan,
#  'CORONA, CA',
#  'LANCASTER, CA',
#  nan,
#  nan,
#  nan,
#  nan,
#  'ENCINO',
# ...

# %%
df.value_counts('PERMIT_TYPE')
# Out:
# PERMIT_TYPE
# Electrical              347111
# Bldg-Alter/Repair       278322
# Plumbing                209081
# HVAC                    107443
# Fire Sprinkler           45189
# Bldg-Addition            39484
# Bldg-New                 28319
# Grading                  22752
# Nonbldg-New              18603
# Swimming-Pool/Spa        16847
# Bldg-Demolition          15519
# Elevator                 14731
# Sign                     13132
# Nonbldg-Alter/Repair      5319
# Pressure Vessel           2129
# Nonbldg-Addition           191
# Nonbldg-Demolition          65
# Bldg-Relocation             13
# dtype: int64

# %%
df.value_counts('APPLICANT_ADDRESS_3')
# Out:
# APPLICANT_ADDRESS_3
# LOS ANGELES, CA        92060
# VAN NUYS, CA           23813
# CANOGA PARK, CA        18311
# NORTH HOLLYWOOD, CA    17049
# WOODLAND HILLS, CA     14207
#                        ...
# INGLEWWOD, CA              1
# INGLEWOOS, CA              1
# INGLEWOOD.CA               1
# INGLEWOOD  CA              1
# | BREA, CA                 1
# Length: 7023, dtype: int64

# %%
brentwood_permits = df[df['APPLICANT_ADDRESS_3'].fillna("").str.contains('BRENTWOOD')]

# %%
brentwood_permits[brentwood_permits['PERMIT_TYPE'].str.contains('Pool')]
# Out:
# Empty DataFrame
# Columns: [ASSESSOR_BOOK, ASSESSOR_PAGE, ASSESSOR_PARCEL, TRACT, BLOCK, LOT, REFERENCE_#_(OLD_PERMIT_#), PCIS_PERMIT_#, PERMIT_TYPE, PERMIT_SUB-TYPE, PERMIT_CATEGORY, PROJECT_NUMBER, EVENT_CODE, INITIATING_OFFICE, ISSUE_DATE, ADDRESS_START, ADDRESS_FRACTION_START, ADDRESS_END, ADDRESS_FRACTION_END, STREET_DIRECTION, STREET_NAME, STREET_SUFFIX, SUFFIX_DIRECTION, UNIT_RANGE_START, UNIT_RANGE_END, ZIP_CODE, WORK_DESCRIPTION, VALUATION, FLOOR_AREA-L.A._ZONING_CODE_DEFINITION, #_OF_RESIDENTIAL_DWELLING_UNITS, #_OF_STORIES, CONTRACTOR'S_BUSINESS_NAME, CONTRACTOR_ADDRESS, CONTRACTOR_CITY, CONTRACTOR_STATE, LICENSE_TYPE, LICENSE_#, PRINCIPAL_FIRST_NAME, PRINCIPAL_MIDDLE_NAME, PRINCIPAL_LAST_NAME, LICENSE_EXPIRATION_DATE, APPLICANT_FIRST_NAME, APPLICANT_LAST_NAME, APPLICANT_BUSINESS_NAME, APPLICANT_ADDRESS_1, APPLICANT_ADDRESS_2, APPLICANT_ADDRESS_3, ZONE, OCCUPANCY, FLOOR_AREA-L.A._BUILDING_CODE_DEFINITION, CENSUS_TRACT, LATITUDE/LONGITUDE]
# Index: []
#
# ...

# %%
df.groupby(['PERMIT_TYPE'],['APPLICANT_ADDRESS_3'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-0e966c7b2f83> in <module>
# ----> 1 df.groupby(['PERMIT_TYPE'],['APPLICANT_ADDRESS_3'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6713         if level is None and by is None:
#    6714             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 6715         axis = self._get_axis_number(axis)
#    6716
#    6717         return DataFrameGroupBy(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     458     def _get_axis_number(cls, axis: Axis) -> int:
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
# ...

# %%
df['PERMIT_SUB-TYPE' , 'APPLICANT_ADDRESS_3'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('PERMIT_SUB-TYPE', 'APPLICANT_ADDRESS_3')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.sort_values['PERMIT_SUB-TYPE'].value_counts('APPLICANT_ADDRESS_3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-59b05dbd63b3> in <module>
# ----> 1 df.sort_values['PERMIT_SUB-TYPE'].value_counts('APPLICANT_ADDRESS_3')
#
# TypeError: 'method' object is not subscriptable

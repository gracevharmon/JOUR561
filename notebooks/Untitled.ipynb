# %%
import pandas as pd
import numpy as np

# %%
requests2016 = pd.read_csv('../data/rawLA311/2016MyLA311ServiceRequestData.csv', low_memory=False)

# %%
requests2017 = pd.read_csv('../data/rawLA311/2017MyLA311ServiceRequestData.csv', low_memory=False)

# %%
requests2018 = pd.read_csv('../data/rawLA311/2018MyLA311ServiceRequestData.csv', low_memory=False)

# %%
requests2019 = pd.read_csv('../data/rawLA311/2019MyLA311ServiceRequestData.csv', low_memory=False)

# %%
requests2020 = pd.read_csv('../data/rawLA311/2020MyLA311ServiceRequestData.csv', low_memory=False)

# %%
requests2021 = pd.read_csv('../data/rawLA311/2021MyLA311ServiceRequestData.csv', low_memory=False)

# %%
requests2016.head(5)
# Out:
#      SRNumber             CreatedDate             UpdatedDate ActionTaken  \
# 0  1-88224881  01/01/2016 08:12:00 AM  01/07/2016 07:39:00 AM  SR Created
# 1  1-88224921  01/01/2016 08:15:00 AM  01/02/2016 07:19:00 AM  SR Created
# 2  1-88225061  01/01/2016 08:26:00 AM  01/04/2016 02:39:00 PM  SR Created
# 3  1-88226921  01/01/2016 08:28:00 AM  01/04/2016 02:52:00 PM  SR Created
# 4  1-88227021  01/01/2016 08:29:00 AM  01/04/2016 12:31:00 PM  SR Created
#
#   Owner                 RequestType  Status RequestSource MobileOS Anonymous  \
# 0   BOS      Illegal Dumping Pickup  Closed          Call      NaN         N
# 1   BOS         Dead Animal Removal  Closed          Call      NaN         Y
# 2   BOS         Dead Animal Removal  Closed          Call      NaN         N
# 3   BOS                 Bulky Items  Closed          Call      NaN         N
# 4   BOS  Metal/Household Appliances  Closed          Call      NaN         N
#
# ...

# %%
df_csv = pd.read_csv('../data/rawLA311/combined.csv', low_memory=False).drop([2123993])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-18-ff105ead7244> in <module>
# ----> 1 df_csv = pd.read_csv('../data/rawLA311/combined.csv', low_memory=False).drop([2123993])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...
